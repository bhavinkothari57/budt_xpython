# %% [markdown]
# ## Project : AirbnbnBoros
#
# ### Team Members : Wei-Cheng, Dhruv Popat, Manasvi Prasad, Bhavin Kothari

# %% [markdown]
# ## INTRODUCTION
#
# #### Since the age of time, lodging business has been available so people could travel and gradually, it became eminent to drive the local economies. Airbnb a revolutionary model in the travel business, has gained popularity to a point where it is becoming a synonym for hotels, killing their business, especially for the price sensitive guests.  It is an online marketplace which lets people or hosts rent out their properties or spare rooms to guests. Since the lodging industry not only depends on the amenities on the property, but also immensely on the facilities around the property. We aiem to analyze how the kind of eateries, shopping hubs, sites for tourists, all make a significant impact on the demand of a listing and draw conclusions that proves useful on multiple levels and not only to Airbnb hosts.
# #### We have successfully merged government records holding the national landmarks in the 5 boroughs that we are considering. We aim to conclude a robust analysis so that it can not only be used by Airbnb hosts, investors, real estate developers but also by government officials to determine the best location and type of a new project.
#
# ![image.png](attachment:image.png)
#
# #### OBJECTIVE
#
# #### We aim to analyze consumer behavior to conclude the factors that drive the popularity of listings. The factors we are most interested in are the keywords, types and amenities around the location of a listing. We hope to develop a robust analysis so that it can not only be used by Airbnb hosts and investors, but also by government to determine the best location and type of a new project.
# #### An underlying assumption that we have made to analyze the data points here is that the number of reviews a listing has, directly correlates to the number of customer transactions and hence, the popularity of the listing. The reasoning behind this is that a listing can not have too many bad reviews, because a place gaining unpopularity would eventually not be receiving reservations and consequently not be reviewed.
#
# #### QUESTIONS OF INTEREST
#
# #### At this point, we are primarily looking to analyze the impact the historic landmarks typically have on the listings, and what drives the popularity of the listings.
#
# ##### 1. What are the types of listings that people prefer in different areas?
#
# ##### 2. What kind of prices prevail in a certain location and what generates this price mechanism?
#
# ##### 3. What keyword in the listings attracts most customers?
#
# ##### 4. How the price, location, review per month affect the popularity for the listing(number of review)?
#
# ##### 5. How to predict price by using varibles?
#
# ##### 6. What area is preferred by hosts with maximum number of rooms?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Our primary data set about Airbnb listings  is from Kaggle. The list of National Historic Landmarks in New York City, that we have picked from wikipedia, required cleaning and merging with our primary data set. We merge both the tables along the 'neighbourhood' column in both datasets. The neighbourhood column in our primary dataset signifies the borough the listing belongs to and the neighbourhood in the secondary dataset signifies the borough the landmark belongs to.
#
# #### •	Find, Merge and Clean the data: The primary dataset and the secondary dataset have been found, merged and cleaned along the desired column.  ---ADD THE DESCRIPTION
#
# #### One primary dataset and one secondary dataset has been successfully found and cleaned and both have been combined along the desired column. The merged data has been made more structured by dropping unnecessary columns and by reordering and renaming the remaining necessary ones. Five finalized datapoints to analyze have been finalized and some more are in consideration. So far, 2 datapoints of the 5 finalized ones have been analyzed.

# %% [markdown]
# ### Importing packages, cause Python Programming!!

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
import plotly.graph_objects as go
mapbox_access_token = 'pk.eyJ1IjoiZGhydXZwb3BhdCIsImEiOiJjazJwZXIzMzQwM2pqM2Ntb3ZlemF6ZWd0In0.an6SvHknkXmjTfPPTafbpw'

# %%
#Scraping data from the Landmarks site for getting to know different landmarks in a Neighbourhood
National_parks_url = 'https://en.wikipedia.org/wiki/List_of_National_Historic_Landmarks_in_New_York_City'
National_parks = pd.read_html(National_parks_url, match = 'Landmark name')[0]

# %%
#Extracting the 3 columns that we are interested in
National_parks_columns = National_parks[['Landmark name', 'County', 'Location']]
National_parks_columns.head()
# Out:
#                               Landmark name    County  \
# 0                      69th Regiment Armory  New York
# 1  Admiral David Glasgow Farragut Gravesite     Bronx
# 2                     African Burial Ground  New York
# 3                       Ambrose (lightship)  New York
# 4          American Stock Exchange Building  New York
#
#                                             Location
# 0  Manhattan 40°44′30″N 73°59′01″W﻿ / ﻿40.741648°...
# 1  Bronx 40°53′32″N 73°51′57″W﻿ / ﻿40.892165°N 73...
# 2  Manhattan 40°42′52″N 74°00′16″W﻿ / ﻿40.714558°...
# 3  Manhattan 40°42′17″N 74°00′09″W﻿ / ﻿40.704844°...
# 4  Manhattan 40°42′32″N 74°00′45″W﻿ / ﻿40.7090°N ...

# %%
#Check the data types for the columns
National_parks_columns.dtypes
# Out:
# Landmark name    object
# County           object
# Location         object
# dtype: object

# %%
#Clean the data in column 'Location' to get the value that we needed
National_parks_columns['Location'] = National_parks_columns['Location'].str.split(' ').str[0]
# Out:
# C:\Users\waifj\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Renamning the colums of the website and get the number of landmarks in each neighbourhood_group
National_parks_columns_df = National_parks_columns.rename(columns={'County': 'neighbourhood_group'})
National_parks_columns_df = National_parks_columns_df.groupby('neighbourhood_group').count()['Location'].to_frame()

# %%
National_parks_columns_df = National_parks_columns_df.reset_index()

# %%
National_parks_columns_df['neighbourhood_group'].unique()
# Out:
# array(['Bronx', 'Kings', 'Kings and New York', 'New York', 'Queens',
#        'Richmond (Staten Island)'], dtype=object)

# %%
National_parks_columns_df['neighbourhood_group'] = ['Bronx', 'Brooklyn', 
                                                 'Kings and New York', 'Manhattan', 'Queens', 
                                                 'Staten Island']

# %%
# The NYC airbnb data set
NYC_airbnb = pd.read_csv('python_airbnb.csv')

# %%
NYC_airbnb['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# ### Merging the landmark data sets with NYC_airbnb

# %%
Join_table = NYC_airbnb.merge(National_parks_columns_df, 
                              left_on='neighbourhood_group', right_on='neighbourhood_group')
Join_table
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          3831                    Cozy Entire Floor of Brownstone       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 4          6848                   Only 2 stops to Manhattan studio      15991
# 5          7097                  Perfect for Your Parents + Garden      17571
# 6          7726    Hip Historic Brownstone Apartment with Backyard      20950
# 7          7801                   Sweet and Spacious Brooklyn Loft      21207
# 8          8024                     CBG CtyBGd HelpsHaiti rm#1:1-4      22486
# 9          8025                           CBG Helps Haiti Room#2.5      22486
# 10         8110                              CBG Helps Haiti Rm #2      22486
# 11         8490             MAISON DES SIRENES1,bohemian apartment      25183
# 12         8505                 Sunny Bedroom Across Prospect Park      25326
# 13         9782                  Loft in Williamsburg Area w/ Roof      32169
# 14        10452                              Large B&B Style rooms      35935
# 15        10962    Lovely room 2 & garden; Best area, Legal rental       9744
# 10                Lisel            Brooklyn                 Park Slope
# 11             Nathalie            Brooklyn         Bedford-Stuyvesant
# 12              Gregory            Brooklyn            Windsor Terrace
# 13               Andrea            Brooklyn                 Greenpoint
# 14               Angela            Brooklyn         Bedford-Stuyvesant
# 15               Laurie            Brooklyn                South Slope
# 16                   Vt            Brooklyn         Bedford-Stuyvesant
# 17               Tyrome            Brooklyn                   Bushwick
# 18              Harriet            Brooklyn                   Flatbush
# 19                Abdul            Brooklyn                South Slope
# 20              Yolande            Brooklyn                Fort Greene
# 21                 Rana            Brooklyn  Prospect-Lefferts Gardens
# 22             Adreinne            Brooklyn         Bedford-Stuyvesant
# 23             Jennifer            Brooklyn         Bedford-Stuyvesant
# 24            Alexander            Brooklyn                Fort Greene
# 25       JT And Tiziana            Brooklyn         Bedford-Stuyvesant
# 26                James            Brooklyn               Williamsburg
# 27               Jeanne            Brooklyn                 Greenpoint
# 28               Joanna            Brooklyn               Williamsburg
# 29               Andrea            Brooklyn                 Greenpoint
# ...                 ...                 ...                        ...
# 48865             James               Bronx             Pelham Gardens
# 48866            Denise               Bronx          Claremont Village
# 48867            Denise               Bronx          Claremont Village
# 48868            Raiysa               Bronx                Parkchester
# 48869             Sayar               Bronx            North Riverdale
# 48870           Dilenny               Bronx                 Pelham Bay
# 48871             Scott               Bronx                Kingsbridge
# 48872             Buddy               Bronx                City Island
# 48873             Buddy               Bronx                City Island
# 48874            Kadeen               Bronx                  Olinville
# 48875          Takeshia               Bronx                   Longwood
# 48876       Jean-Joseph               Bronx                Port Morris
# 48877          Pi & Leo               Bronx                    Fordham
# 48878          Pi & Leo               Bronx                    Fordham
# 48879          Pi & Leo               Bronx                    Fordham
# 48880          Pi & Leo               Bronx                    Fordham
# 48881           Francis               Bronx               Clason Point
# 48882       Lee & Luffy               Bronx                Castle Hill
# 48883       Lee & Luffy               Bronx                Castle Hill
# 48884       Lee & Luffy               Bronx                Castle Hill
# 48885       Lee & Luffy               Bronx                Castle Hill
# 48886       Lee & Luffy               Bronx                Castle Hill
# 48887       Lee & Luffy               Bronx                Castle Hill
# 48888       Lee & Luffy               Bronx                Castle Hill
# 48889             Bryan               Bronx                 Pelham Bay
# 48890               Jay               Bronx          Claremont Village
# 48891          Carolina               Bronx                 Morrisania
# 48892         Dominique               Bronx          Claremont Village
# 48893           Chantal               Bronx          Concourse Village
# 48894            Blaine               Bronx                 Mott Haven
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0      40.64749  -73.97237     Private room    149               1
# 1      40.68514  -73.95976  Entire home/apt     89               1
# 2      40.68688  -73.95596     Private room     60              45
# 3      40.66829  -73.98779     Private room     89               4
# 4      40.70837  -73.95352  Entire home/apt    140               2
# 5      40.69169  -73.97185  Entire home/apt    215               2
# 6      40.67592  -73.94694  Entire home/apt     99               3
# 7      40.71842  -73.95718  Entire home/apt    299               3
# 8      40.68069  -73.97706     Private room    130               2
# 9      40.67989  -73.97798     Private room     80               1
# 10     40.68001  -73.97865     Private room    110               2
# 11     40.68371  -73.94028  Entire home/apt    120               2
# 12     40.65599  -73.97519     Private room     60               1
# 13     40.72219  -73.93762     Private room     55               4
# 18                     0         NaN                NaN
# 19                    15   5/27/2019               0.39
# 20                    25   9/30/2018               0.23
# 21                    11    6/5/2019               0.49
# 22                    61   5/25/2019               0.52
# 23                    11    1/1/2017               0.10
# 24                   135   6/17/2019               1.16
# 25                   112   6/16/2019               1.01
# 26                    82   5/17/2019               0.70
# 27                   328   6/29/2019               2.82
# 28                   105   6/22/2019               0.90
# 29                   138    6/4/2019               1.19
# ...                  ...         ...                ...
# 48865                  1   6/26/2019               1.00
# 48866                  0         NaN                NaN
# 48867                  0         NaN                NaN
# 48868                  1   6/28/2019               1.00
# 48869                  0         NaN                NaN
# 48870                  0         NaN                NaN
# 48871                  0         NaN                NaN
# 48872                  0         NaN                NaN
# 48873                  0         NaN                NaN
# 48874                  0         NaN                NaN
# 48875                  1    7/6/2019               1.00
# 48876                  0         NaN                NaN
# 48877                  0         NaN                NaN
# 48878                  0         NaN                NaN
# 48879                  0         NaN                NaN
# 48880                  0         NaN                NaN
# 48881                  0         NaN                NaN
# 48882                  0         NaN                NaN
# 48883                  0         NaN                NaN
# 48884                  0         NaN                NaN
# 48885                  0         NaN                NaN
# 48886                  0         NaN                NaN
# 48887                  0         NaN                NaN
# 48888                  0         NaN                NaN
# 48889                  0         NaN                NaN
# 48890                  0         NaN                NaN
# 48891                  0         NaN                NaN
# 48892                  0         NaN                NaN
# 48893                  0         NaN                NaN
# 48894                  2    7/7/2019               2.00
#
#        calculated_host_listings_count  availability_365  Location
# 0                                   6               365         9
# 1                                   1               194         9
# 2                                   1                 0         9
# 3                                   3               314         9
# 4                                   1                46         9
# 5                                   1               321         9
# 6                                   1                21         9
# 7                                   1                 0         9
# 8                                   6               347         9
# 9                                   6               364         9
# 10                                  6               304         9
# 11                                  2               233         9
# 12                                  2                85         9
# 13                                  3               284         9
# 14                                  2               269         9
# 15                                  3               340         9
# 16                                  1               365         9
# 17                                  2                22         9
# 18                                  1               365         9
# 19                                  1               345         9
# 20                                  1               311         9
# 21                                  1                95         9
# 22                                  1               265         9
# 23                                  1                 0         9
# 24                                  2               192         9
# 25                                  3               251         9
# 26                                  1               140         9
# 27                                  1               234         9
# 28                                  1                30         9
# 29                                  3               320         9
# ...                               ...               ...       ...
# 48865                               2               354         8
# 48866                               2               348         8
# 48867                               2               166         8
# 48868                               1                68         8
# 48869                               1                89         8
# 48870                               1               179         8
# 48871                               1               115         8
# 48872                               4                90         8
# 48873                               4                44         8
# 48874                               1               190         8
# 48875                               1                14         8
# 48876                               1               290         8
# 48877                               8                58         8
# 48878                               8                89         8
# 48879                               8                81         8
# 48880                               8                84         8
# 48881                               1               167         8
# 48882                               7               169         8
# 48883                               7               167         8
# 48884                               7               177         8
# 48885                               7               177         8
# 48886                               7               177         8
# 48887                               7               177         8
# 48888                               7               177         8
# 48889                               1                88         8
# 48890                               1                90         8
# 48891                               1                71         8
# 48892                               1               364         8
# 48893                               2                81         8
# 48894                               1                40         8
#
# [48895 rows x 17 columns]

# %% [markdown]
# # Trying to find some correlation between price and number of reviews

# %%
df1 = Join_table[Join_table['availability_365'] != 0]
df1[['number_of_reviews','price']].corr()
# Out:
#                    number_of_reviews     price
# number_of_reviews           1.000000 -0.072919
# price                      -0.072919  1.000000

# %% [markdown]
# #### We thought price would have a strong relation with number of reviews, but we find that there is no strict correlation between them.

# %% [markdown]
# # What type of listings cost the most and by how much do they differ?

# %%
fig, (ax, ax1, ax2, ax3, ax7) = plt.subplots(1, 5, sharey=True, figsize=(15,7))


df1 = Join_table[Join_table['neighbourhood_group'] == 'Manhattan'].reset_index()
df2 = Join_table[Join_table['neighbourhood_group'] == 'Brooklyn'].reset_index()
df3 = Join_table[Join_table['neighbourhood_group'] == 'Queens'].reset_index()
df4 = Join_table[Join_table['neighbourhood_group'] == 'Bronx'].reset_index()
df5 = Join_table[Join_table['neighbourhood_group'] == 'Staten Island'].reset_index()

group=df1.groupby('room_type')['price'].mean().plot.bar(ax=ax, color=['r','b','b'], title = 'Manhattan')
group2=df2.groupby('room_type')['price'].mean().plot.bar(ax=ax1, color=['r','b','b'], title='Brooklyn')
group3=df3.groupby('room_type')['price'].mean().plot.bar(ax=ax2, color=['r','b','b'], title='Queens')
group4=df4.groupby('room_type')['price'].mean().plot.bar(ax=ax3, color=['r','b','b'], title='Bronx')
group5=df5.groupby('room_type')['price'].mean().plot.bar(ax=ax7, color=['r','b','b'],title='Staten Island')

# %% [markdown]
# #### We note that private rooms in Manhattan cost almost as much as an entire appartment in Bronx. The contrast is not very stark between types of listings in Queens and Bronx

# %% [markdown]
# # Preferences of People in different boroughs

# %%
fig, (ax, ax1, ax2, ax3, ax7) = plt.subplots(1, 5, sharey=True, figsize=(15,7))


df1 = Join_table[Join_table['neighbourhood_group'] == 'Manhattan'].reset_index()
df2 = Join_table[Join_table['neighbourhood_group'] == 'Brooklyn'].reset_index()
df3 = Join_table[Join_table['neighbourhood_group'] == 'Queens'].reset_index()
df4 = Join_table[Join_table['neighbourhood_group'] == 'Bronx'].reset_index()
df5 = Join_table[Join_table['neighbourhood_group'] == 'Staten Island'].reset_index()

group =df1.groupby('room_type')['price'].count().plot.bar(ax=ax, color=['r','b','b'], title = 'Manhattan')
group2=df2.groupby('room_type')['price'].count().plot.bar(ax=ax1, color=['r','b','b'], title='Brooklyn')
group3=df3.groupby('room_type')['price'].count().plot.bar(ax=ax2, color=['r','b','b'], title='Queens')
group4=df4.groupby('room_type')['price'].count().plot.bar(ax=ax3, color=['r','b','b'], title='Bronx')
group5=df5.groupby('room_type')['price'].count().plot.bar(ax=ax7, color=['r','b','b'],title='Staten Island')

# %% [markdown]
# #### We conclude that in Manhattan people prefer Entire Apartment and in Queens and Bronx private rooms are more prevalent. Can we conclude that people travelling to Manhattan often go with friends or in groups? What do you think causes this disparity?

# %% [markdown]
# # The trends of high end properties in NYC - A Visual Story

# %%
L1 = []

for i in range(Join_table.shape[0]):
    if (Join_table['room_type'][i] == 'Private room' and Join_table['price'][i] > 250):
        L1.append(Join_table.iloc[i,:])

new_df = pd.DataFrame(L1)
new_df.head()
# Out:
#          id                                  name  host_id  \
# 148   80684   Duplex w/ Terrace @ Box House Hotel   417504
# 149   80700     Loft w/ Terrace @ Box House Hotel   417504
# 174  103311     2 BR w/ Terrace @ Box House Hotel   417504
# 297  241140  The Notorious B.N.B. { The Wallace }  1177497
# 299  242532    The Notorious B.N.B. { The Swoon }  1177497
#
#                host_name neighbourhood_group neighbourhood  latitude  \
# 148  The Box House Hotel            Brooklyn    Greenpoint  40.73776
# 149  The Box House Hotel            Brooklyn    Greenpoint  40.73738
# 174  The Box House Hotel            Brooklyn    Greenpoint  40.73861
# 297              Jessica            Brooklyn  Clinton Hill  40.68975
# 299              Jessica            Brooklyn  Clinton Hill  40.68930
#
#      longitude     room_type  price  minimum_nights  number_of_reviews  \
# 148  -73.95327  Private room    349               3                  8
# 149  -73.95482  Private room    349               3                  7
# 174  -73.95485  Private room    599               3                  9
# 297  -73.96703  Private room    438               1                 43
# 299  -73.96602  Private room    279               1                120
#
#     last_review  reviews_per_month  calculated_host_listings_count  \
# 148   3/27/2016               0.09                              28
# 149   5/24/2019               0.07                              28
# 174   5/19/2018               0.09                              28
# 297   4/14/2019               0.46                              11
# 299   6/19/2019               1.28                              11
#
#      availability_365  Location
# 148                60         9
# 149                60         9
# 174                60         9
# 297               363         9
# 299               362         9

# %%
class_map_data1 = go.Scattermapbox(
    
        
        lon = new_df[new_df['neighbourhood_group']=='Brooklyn' ]['longitude'] ,
        lat = new_df[new_df['neighbourhood_group']=='Brooklyn']['latitude'] ,
        text = new_df['name'],
        hoverinfo='text',
        mode = 'markers',
        marker = dict(
                    color = 'red',
                    symbol = 'circle',
                    opacity = .5
            ),
        name = "Brooklyn"
)

class_map_data2 = go.Scattermapbox(
    
        
        lon = new_df[new_df['neighbourhood_group']== 'Bronx'] ['longitude'],
        lat = new_df[new_df['neighbourhood_group']== 'Bronx'] ['latitude'],
        text = new_df['name'],
        hoverinfo='text',
        mode = 'markers',
        marker = dict(
                    color = 'blue',
                    symbol = 'circle',
                    opacity = .5
            ),
        name = "Bronx"
)


class_map_data3 = go.Scattermapbox(
    
        
        lon = new_df[new_df['neighbourhood_group']== 'Manhattan'] ['longitude'],
        lat = new_df[new_df['neighbourhood_group']== 'Manhattan'] ['latitude'],
        text = new_df['name'],
        hoverinfo='text',
        mode = 'markers',
        marker = dict(
                    color = 'yellow',
                    symbol = 'circle',
                    opacity = .5
            ),
        name = "Manhattan"
)


class_map_data4 = go.Scattermapbox(
    
        
        lon = new_df[new_df['neighbourhood_group']== 'Queens'] ['longitude'],
        lat = new_df[new_df['neighbourhood_group']== 'Queens'] ['latitude'],
        text = new_df['name'],
        hoverinfo='text',
        mode = 'markers',
        marker = dict(
                    color = 'purple',
                    symbol = 'circle',
                    opacity = .5
            ),
        name = "Queens"
)


class_map_data5 = go.Scattermapbox(
    
        
        lon = new_df[new_df['neighbourhood_group']== 'Staten Island'] ['longitude'],
        lat = new_df[new_df['neighbourhood_group']== 'Staten Island'] ['latitude'],
        text = new_df['name'],
        hoverinfo='text',
        mode = 'markers',
        marker = dict(
                    color = 'green',
                    symbol = 'circle',
                    opacity = .5
            ),
        name = "Staten Island"
)

ex w/ Terrace @ Box House Hotel", "Loft w/ Terrace @ Box House Hotel", "2 BR w/ Terrace @ Box House Hotel", "The Notorious B.N.B. { The Wallace }", "The Notorious B.N.B. { The Swoon }", "Duplex w/ Terrace @ Box House Hotel", "1 BR w/ Terrace @ Box House Hotel", "2 BR Duplex @ Box House Hotel", "Loft Room in Heart of Williamsburg", "Marcel the Shell with Shoes On or Off, Whatever", "BROOKLYN'S FAVORITE BROWNSTONE in HIPSTER BED-STUY", "NearWilliamsburg bridge 11211 BK", "Cute Room, Courteous Hosts", "Private cozy Bedroom in Brooklyn ", "Cozy bedroom in Brooklyn Sunsetpark", "Room in Clean/Quiet/Funky Space!", "The Notorious B.N.B. { The William Henry }", "Large room in newly renovated apt", "NY Executive Apartment", "Spacious private room", "Private Room in New Bed-Stuy Lofts", "Lovely, Room/with Private bathroom", "Room in pre-war space", "Williamsburg 2000sqft", "Entire pvt. house for rent ,2 floors\n 3 bdrms., 2.5  baths. Newly renovated,avail. From Nov (Phone number hidden by Airbnb) thru April (Phone number hidden by Airbnb) / month", "Prime Williamsburg Spacious Duplex + Huge Yard", "Private Room in Williamsburg!", "Giant Landmark Apartment in the Sky", "Perfect Neighborhood sublet", "Sunny Williamsburg Sublet", "Private Room in Williamsburg Duplex", "Bright & Cozy Furnitured 4 Sublet", "Elgant double bed room in Brooklyn.", "Large deluxe queen size bedroom", "Event Space | Backyard | Pool", "Lovely S.Slope 3BR in 4BR 1300 sf dplx,deck&birds!", "Large Bedroom for $750 Monthly", "Private Room in Elevator building in Brooklyn", "889 Bushwick Ave", "ARTIST LOFT in WILLIAMSBURG", "Harrigan Luxury Townhouse  ...

# %% [markdown]
# #### We can see that the most expensive houses are situated in Manhattan (Duh! Obviously)

# %% [markdown]
# # Do certain words in description have a better impact on the psyche of the tourist? Lets find out...
#
# ### We have caculated the frequency of words in the description of the properties. The aim is to highlight keywords which are the most impactful towards popularity of the listings. In order to do so, we have manually extracted meaningful key words which have a frequency of more than 1000, that is they occur more than 1000 times in the descriptions. The average review per month corresponding to every meaningful key word has been calculated. We observe that the extracted key words have outstanding average reviews per month and we suggest that these key words could be used by hosts looking to enlist their porperties too, as this attracts more customers, popularity and consequently more reviews.

# %% [markdown]
# # Do certain words in description have a better impact on the psyche of the tourist? Lets find out...

# %%
wordsSeries = Join_table['name'].str.split(' ')
wordsSeries
# Out:
# 0              [Clean, &, quiet, apt, home, by, the, park]
# 1                    [Cozy, Entire, Floor, of, Brownstone]
# 2                                        [BlissArtsSpace!]
# 3        [Lovely, Room, 1,, Garden,, Best, Area,, Legal...
# 4                  [Only, 2, stops, to, Manhattan, studio]
# 5                 [Perfect, for, Your, Parents, +, Garden]
# 6        [Hip, Historic, Brownstone, Apartment, with, B...
# 7                   [Sweet, and, Spacious, Brooklyn, Loft]
# 8                      [CBG, CtyBGd, HelpsHaiti, rm#1:1-4]
# 9                            [CBG, Helps, Haiti, Room#2.5]
# 10                             [CBG, Helps, Haiti, Rm, #2]
# 11             [MAISON, DES, SIRENES1,bohemian, apartment]
# 12                [Sunny, Bedroom, Across, Prospect, Park]
# 13                [Loft, in, Williamsburg, Area, w/, Roof]
# 14                              [Large, B&B, Style, rooms]
# 15       [Lovely, room, 2, &, garden;, Best, area,, Leg...
# 16                       [Clean, and, Quiet, in, Brooklyn]
# 17                         [Cute, apt, in, artist's, home]
# 18                         [Country, space, in, the, city]
# 19               [Beautiful, Sunny, Park, Slope, Brooklyn]
# 20               [1bdr, w, private, bath., in, lofty, apt]
# 21       [Entire, apartment, in, central, Brooklyn, nei...
# 22               [Charming, Brownstone, 3, -, Near, PRATT]
# 23                          [bright, and, stylish, duplex]
# 24                            [Fort, Greene, brownstone, ]
# 25       [Blue, Room, for, 2, in, Brownstone, for, $135...
# 26                        [*, ORIGINAL, BROOKLYN, LOFT, *]
# 27                   [Greenpoint, Place...Has, It, All!, ]
# 28                   [Williamsburg, 1, bedroom, Apartment]
# 29                  [Room, in, Greenpoint, Loft, w/, Roof]
#                                ...
# 48865    [Great, Apartment, only, $79, per, night, \nGr...
# 48866                                    [The, Game, Room]
# 48867                             [The, Game, Room, Place]
# 48868        [Bright, and, Sunny, home, away, from, home.]
# 48869       [Modern, and, Beautiful, Riverdale, Apartment]
# 48870                                         [Cozy, warm]
# 48871    [The, place, is, a, brand, new, gut, renovated...
# 48872                         [VJ'S, 5, HOUR, YACHT, TOUR]
# 48873      [ROMANTIC, SUNSET, YACHT, CRUISE, &, FIREWORKS]
# 48874    [Furnished, room, , for, rent, in, Bronx, SING...
# 48875               [Best, 1, bedroom, apartment, in, NYC]
# 48876                                     [NYC, Cozy, Apt]
# 48877                [spacious, space, privated, room, #1]
# 48878    [Brand, New, Private, 5, bedrooms, apartment, ...
# 48879                        [Spacious, private, room, #2]
# 48880                        [spacious, private, room, #3]
# 48881                                       [Dream, House]
# 48882    [Spacious, brand, new, 2, bedrooms, apartment,...
# 48883    [Cozy, brand, new, 3, bedrooms, apartment,, Hu...
# 48884          [Cozy, Spacious, Queens, Private, Room, #1]
# 48885                [Get, Away, NYC, Queens, Bedroom, #2]
# 48886        [NYC, Traveler, Get, Away, Private, ROOM, #3]
# 48887    [Spacious, brand, new, room, getaway, traveler...
# 48888     [Brand, New, Privated, Room, for, NYC, Traveler]
# 48889             [Shared, living, space, in, the, Bronx!]
# 48890                                [Best, room, in, nyc]
# 48891                          [Private, house, Apartment]
# 48892    [Cute, double, room, for, the, perfect, Yankee...
# 48893    [1A., Studio, &, Stay., 30, minutes, to, Midto...
# 48894                  [1B-1B, apartment, near, by, Metro]
# Name: name, Length: 48895, dtype: object

# %%
wordsSeries = wordsSeries.dropna()

# %%
dic = {}
for words in wordsSeries:
    for word in words:
        if word not in dic:
            dic[word] = 1
        else:
            dic[word] += 1

# %%
import operator
sorted_dic = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)

# %%
from wordcloud import WordCloud, ImageColorGenerator

# %%
#from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in Join_table.name)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200, background_color="yellow").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#printing some values of sorted_dic
sorted_dic[0:10]
# Out:
# [('in', 15796),
#  ('Private', 4967),
#  ('Room', 4803),
#  ('room', 4165),
#  ('Bedroom', 4124),
#  ('Cozy', 3812),
#  ('Apartment', 3633),
#  ('to', 3560),
#  ('Brooklyn', 3471),
#  ('1', 3354)]

# %%
MostFrequencyKeywords = ['Private','Brooklyn','Cozy','East','Studio','Spacious',
                         'Park','Williamsburg','Manhattan','Sunny','Village','Beautiful','Central',
                         'West','Large','Loft','Modern','Upper','Luxury','Side',
                         'Charming','heart','Bushwick','Bright']
# Etrack attractive description key words which appear more than 1000 times

# %%
Join_table.head()
# Out:
#      id                                            name  host_id  \
# 0  2539              Clean & quiet apt home by the park     2787
# 1  3831                 Cozy Entire Floor of Brownstone     4869
# 2  5121                                 BlissArtsSpace!     7356
# 3  5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 4  6848                Only 2 stops to Manhattan studio    15991
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           John            Brooklyn          Kensington  40.64749  -73.97237
# 1    LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2          Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3         Laurie            Brooklyn         South Slope  40.66829  -73.98779
# 4  Allen & Irina            Brooklyn        Williamsburg  40.70837  -73.95352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  10/19/2018
# 1  Entire home/apt     89               1                270    7/5/2019
# 2     Private room     60              45                 49   10/5/2017
# 3     Private room     89               4                167   6/24/2019
# 4  Entire home/apt    140               2                148   6/29/2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               4.64                               1               194
# 2               0.40                               1                 0
# 3               1.34                               3               314
# 4               1.20                               1                46
#
#    Location
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9

# %%
nameReivew = Join_table[['id', 'name', 'reviews_per_month']]

# %%
nameReivew.head()
# Out:
#      id                                            name  reviews_per_month
# 0  2539              Clean & quiet apt home by the park               0.21
# 1  3831                 Cozy Entire Floor of Brownstone               4.64
# 2  5121                                 BlissArtsSpace!               0.40
# 3  5803  Lovely Room 1, Garden, Best Area, Legal rental               1.34
# 4  6848                Only 2 stops to Manhattan studio               1.20

# %%
nameReivew = nameReivew.dropna()

# %%
nameReivew = nameReivew.reset_index(drop = True)

# %%
len(MostFrequencyKeywords)
# Out:
# 24

# %%
dictOfWords = { i : [] for i in MostFrequencyKeywords }

# %%
nameReivew['name'] = nameReivew['name'].str.split(' ')

# %%
for i in range(len(nameReivew['name'])):
        for keyword in MostFrequencyKeywords:
            if keyword in nameReivew['name'][i]:
                dictOfWords[keyword].append(nameReivew['reviews_per_month'][i])

# %%
for keyword in dictOfWords:
    dictOfWords[keyword] = sum(dictOfWords[keyword])/len(dictOfWords[keyword])

# %%
dictOfWords
# Out:
# {'Private': 1.6672492552135085,
#  'Brooklyn': 1.2967902946273835,
#  'Cozy': 1.4868643533123058,
#  'East': 1.1243124999999985,
#  'Studio': 1.225477528089885,
#  'Spacious': 1.093484646194924,
#  'Park': 1.3390996784565898,
#  'Williamsburg': 1.029652025099829,
#  'Manhattan': 1.6153231939163528,
#  'Sunny': 1.0504221165279417,
#  'Village': 1.00542800265428,
#  'Beautiful': 1.2678580645161273,
#  'Central': 1.6136567164179088,
#  'West': 0.953128103277061,
#  'Large': 1.051615320566193,
#  'Loft': 1.0424311490978153,
#  'Modern': 1.4621062271062277,
#  'Upper': 1.0367185761957733,
#  'Luxury': 1.2473290598290592,
#  'Side': 1.0943550295857989,
#  'Charming': 1.2054754098360634,
#  'heart': 1.285463800904976,
#  'Bushwick': 1.2145668316831688,
#  'Bright': 1.196271739130435}

# %%
key = list(dictOfWords.keys())

# %%
value = list(dictOfWords.values())

# %%
sns.barplot(x=key, y= value)
plt.xticks(rotation=90)
plt.title("Key words with reviews per month ")
# Out:
# Text(0.5, 1.0, 'Key words with reviews per month ')

# %%
avg = sum(nameReivew['reviews_per_month'])/len(nameReivew['reviews_per_month'])

# %%
avg
# Out:
# 1.3734098926281644

# %%
for i in dictOfWords:
    if dictOfWords[i] > avg:
        print('When {} is in the description, average reviews per month go to {}'.format(i, dictOfWords[i]))
# Out:
# When Private is in the description, average reviews per month go to 1.6672492552135085
# When Cozy is in the description, average reviews per month go to 1.4868643533123058
# When Manhattan is in the description, average reviews per month go to 1.6153231939163528
# When Central is in the description, average reviews per month go to 1.6136567164179088
# When Modern is in the description, average reviews per month go to 1.4621062271062277

# %% [markdown]
# ### As observed, Private, Cozy, Manhattan, Central and Modern are 5 words that have outstanding rate of reviews per month and these are the few of several popular words that both hosts and guests could look for.

# %% [markdown]
# # How the price affect the popularity for the listing(number of review)?

# %% [markdown]
# ### In order to find how price affects the popularity of a lisiting, we have created four bins for price. Next, we have created a bar plot where each color represents different neighbourhood groups while y xais represents the number of reviews per month. we can observe here that in each price bin, Manhattan and Brooklyn have lower number of reviews than other three neighbourhood groups.

# %%
Join_table.head()
# Out:
#      id                                            name  host_id  \
# 0  2539              Clean & quiet apt home by the park     2787
# 1  3831                 Cozy Entire Floor of Brownstone     4869
# 2  5121                                 BlissArtsSpace!     7356
# 3  5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 4  6848                Only 2 stops to Manhattan studio    15991
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           John            Brooklyn          Kensington  40.64749  -73.97237
# 1    LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2          Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3         Laurie            Brooklyn         South Slope  40.66829  -73.98779
# 4  Allen & Irina            Brooklyn        Williamsburg  40.70837  -73.95352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  10/19/2018
# 1  Entire home/apt     89               1                270    7/5/2019
# 2     Private room     60              45                 49   10/5/2017
# 3     Private room     89               4                167   6/24/2019
# 4  Entire home/apt    140               2                148   6/29/2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               4.64                               1               194
# 2               0.40                               1                 0
# 3               1.34                               3               314
# 4               1.20                               1                46
#
#    Location
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9

# %%
# %pylab inline
import datetime as dt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\waifj\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning:
#
# pylab import has clobbered these variables: ['text']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
Join_table['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
Join_table = Join_table.dropna()

# %%
Join_table['price_bin'] = pd.cut(x=Join_table['price'], bins=[0,69,106,175,10000])
# Out:
# C:\Users\waifj\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Join_table.head()
# Out:
#      id                                            name  host_id  \
# 0  2539              Clean & quiet apt home by the park     2787
# 1  3831                 Cozy Entire Floor of Brownstone     4869
# 2  5121                                 BlissArtsSpace!     7356
# 3  5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 4  6848                Only 2 stops to Manhattan studio    15991
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           John            Brooklyn          Kensington  40.64749  -73.97237
# 1    LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2          Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3         Laurie            Brooklyn         South Slope  40.66829  -73.98779
# 4  Allen & Irina            Brooklyn        Williamsburg  40.70837  -73.95352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  10/19/2018
# 1  Entire home/apt     89               1                270    7/5/2019
# 2     Private room     60              45                 49   10/5/2017
# 3     Private room     89               4                167   6/24/2019
# 4  Entire home/apt    140               2                148   6/29/2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               4.64                               1               194
# 2               0.40                               1                 0
# 3               1.34                               3               314
# 4               1.20                               1                46
#
#    Location   price_bin
# 0         9  (106, 175]
# 1         9   (69, 106]
# 2         9     (0, 69]
# 3         9   (69, 106]
# 4         9  (106, 175]

# %% [markdown]
# # Graph of number of reviews by Price range in different neighbourhood groups

# %%
sns.barplot(x=Join_table['price_bin'], y=Join_table['reviews_per_month'], hue=Join_table['neighbourhood_group']);
plt.xticks(rotation=45);
plt.title("Reviews per month vs Price(by Cut) in different neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Reviews per month vs Price(by Cut) in different neighbourhood group')

# %% [markdown]
# # Predict price by using Linear Regression

# %% [markdown]
# ### Having converted the room types and neighbourhood groups to numerical categorical data and having removed the data of availability_365 = 0 from our considerations as it's unlikely that owners don't bother to rent out their homes even once a year have updated prices, we hope to attain a better model. We have used Heatmap to check the disturbing factor of intermediate variables and select the variable to our regression model. We have also removed outliers by observing the graph plotted by error_frame and have fit the model again. As expected, this model is much better than before as R2 value is higher and Actual and Predicted model have much better fitting.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Join_table = Join_table.rename(columns={'name': 'Description', 'id':'RoomId','Location':'Numbers of Landmark in neighbourhood_group' })

# %%
df = Join_table.copy()
df.head()
# Out:
#    RoomId                                     Description  host_id  \
# 0    2539              Clean & quiet apt home by the park     2787
# 1    3831                 Cozy Entire Floor of Brownstone     4869
# 2    5121                                 BlissArtsSpace!     7356
# 3    5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 4    6848                Only 2 stops to Manhattan studio    15991
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           John            Brooklyn          Kensington  40.64749  -73.97237
# 1    LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2          Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3         Laurie            Brooklyn         South Slope  40.66829  -73.98779
# 4  Allen & Irina            Brooklyn        Williamsburg  40.70837  -73.95352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  10/19/2018
# 1  Entire home/apt     89               1                270    7/5/2019
# 2     Private room     60              45                 49   10/5/2017
# 3     Private room     89               4                167   6/24/2019
# 4  Entire home/apt    140               2                148   6/29/2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               4.64                               1               194
# 2               0.40                               1                 0
# 3               1.34                               3               314
# 4               1.20                               1                46
#
#    Numbers of Landmark in neighbourhood_group   price_bin
# 0                                           9  (106, 175]
# 1                                           9   (69, 106]
# 2                                           9     (0, 69]
# 3                                           9   (69, 106]
# 4                                           9  (106, 175]

# %%
#Convert the room types and neighbourhood groups to numerical categorical data.
df['room_type'] = df['room_type'].astype('category').cat.codes
df['neighbourhood_group'] = df['neighbourhood_group'].astype('category').cat.codes
f, axs = plt.subplots(1,2, figsize=(12,5))
sns.countplot(df['room_type'], ax=axs[0], order=df['room_type'].value_counts().index)
sns.countplot(df['neighbourhood_group'],order=df['neighbourhood_group'].value_counts().index, ax=axs[1])

# %% [markdown]
# ### Many owners don't rent out their properties for even a single day in an year.
# ### It's unlikely that owners that don't bother to rent out their homes even once a year are updated with the prices,  so we will remove them from our considerations.

# %%
print(df.shape)
df = df[df['availability_365']!=0]
print(df.shape) #New DF shape
# Out:
# (38821, 18)
# (26146, 18)

# %%
df.head()
# Out:
#    RoomId                                     Description  host_id  \
# 0    2539              Clean & quiet apt home by the park     2787
# 1    3831                 Cozy Entire Floor of Brownstone     4869
# 3    5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 4    6848                Only 2 stops to Manhattan studio    15991
# 5    7097               Perfect for Your Parents + Garden    17571
#
#        host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0           John                    1    Kensington  40.64749  -73.97237
# 1    LisaRoxanne                    1  Clinton Hill  40.68514  -73.95976
# 3         Laurie                    1   South Slope  40.66829  -73.98779
# 4  Allen & Irina                    1  Williamsburg  40.70837  -73.95352
# 5           Jane                    1   Fort Greene  40.69169  -73.97185
#
#    room_type  price  minimum_nights  number_of_reviews last_review  \
# 0          1    149               1                  9  10/19/2018
# 1          0     89               1                270    7/5/2019
# 3          1     89               4                167   6/24/2019
# 4          0    140               2                148   6/29/2019
# 5          0    215               2                198   6/28/2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               4.64                               1               194
# 3               1.34                               3               314
# 4               1.20                               1                46
# 5               1.72                               1               321
#
#    Numbers of Landmark in neighbourhood_group     price_bin
# 0                                           9    (106, 175]
# 1                                           9     (69, 106]
# 3                                           9     (69, 106]
# 4                                           9    (106, 175]
# 5                                           9  (175, 10000]

# %%
df.drop(['RoomId', 'Description', 'host_id', 'host_name', 'neighbourhood', 'last_review'], axis=1, inplace=True)

# %% [markdown]
# ### We will drop features that are unlikely to affect the price - ID, name, host_id, host_name. We will also drop features that have largely incomplete data - last_review, reviews_per_month or have too many categories - neighbourhood.

# %%
df.drop(['price_bin'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    neighbourhood_group  latitude  longitude  room_type  price  minimum_nights  \
# 0                    1  40.64749  -73.97237          1    149               1
# 1                    1  40.68514  -73.95976          0     89               1
# 3                    1  40.66829  -73.98779          1     89               4
# 4                    1  40.70837  -73.95352          0    140               2
# 5                    1  40.69169  -73.97185          0    215               2
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                270               4.64                               1
# 3                167               1.34                               3
# 4                148               1.20                               1
# 5                198               1.72                               1
#
#    availability_365  Numbers of Landmark in neighbourhood_group
# 0               365                                           9
# 1               194                                           9
# 3               314                                           9
# 4                46                                           9
# 5               321                                           9

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr().round(4), annot=True)

# %% [markdown]
# ### Heatmap to check the disturbing factor of intermediate variables

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
Y = df['price']
X = df[['neighbourhood_group', 'longitude', 'room_type', 'availability_365', 'calculated_host_listings_count',
        'Numbers of Landmark in neighbourhood_group', 'reviews_per_month','latitude','number_of_reviews']]
X = preprocessing.normalize(X)
X = np.hstack((np.ones( (len(df['price']) ,1)), X))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (20916, 10)
# (5230, 10)
# (20916,)
# (5230,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

lin_model = LinearRegression().fit(X_train, Y_train)

# %%
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 187.72392443782243
# R2 score is 0.0971370164195614
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 194.6402628160994
# R2 score is 0.08853676083786555

# %% [markdown]
# ### Lower values of RMSE indicate better fit. RMSE is a good measure of how accurately the model predicts the response, and it is the most important criterion for fit if the main purpose of the model is prediction

# %%
error_frame = pd.DataFrame({'Actual': np.array(Y_test).flatten(), 'Predicted': y_test_predict.flatten()})
error_frame.head(10)
# Out:
#    Actual   Predicted
# 0     140  148.775851
# 1     125  116.472905
# 2     130  229.837177
# 3      90  222.731884
# 4      33  120.560247
# 5      95    7.360453
# 6      70   54.432198
# 7     125  147.718261
# 8     256  239.106587
# 9      80  123.268393

# %%
df1 = error_frame[:50]
df1.plot(kind='bar',figsize=(24,20))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# # Since Our R2 score is very bad, our model is not perfect. So we remove outliers and try to fit it again.

# %%
#We will use the IQR metric to remove outliers, then fit again.
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
IQR_df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
IQR_df.shape
# Out:
# (15945, 11)

# %%
df.head()
# Out:
#    neighbourhood_group  latitude  longitude  room_type  price  minimum_nights  \
# 0                    1  40.64749  -73.97237          1    149               1
# 1                    1  40.68514  -73.95976          0     89               1
# 3                    1  40.66829  -73.98779          1     89               4
# 4                    1  40.70837  -73.95352          0    140               2
# 5                    1  40.69169  -73.97185          0    215               2
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                270               4.64                               1
# 3                167               1.34                               3
# 4                148               1.20                               1
# 5                198               1.72                               1
#
#    availability_365  Numbers of Landmark in neighbourhood_group
# 0               365                                           9
# 1               194                                           9
# 3               314                                           9
# 4                46                                           9
# 5               321                                           9

# %%
Y = IQR_df['price']
X = IQR_df[['neighbourhood_group', 'longitude', 'room_type', 'availability_365', 'calculated_host_listings_count',
        'Numbers of Landmark in neighbourhood_group', 'reviews_per_month','latitude','number_of_reviews']]
X = preprocessing.normalize(X)
X = np.hstack((np.ones( (len(IQR_df['price']) ,1)), X))


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (12756, 10)
# (3189, 10)
# (12756,)
# (3189,)

# %%
lin_model = LinearRegression().fit(X_train, Y_train)
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 53.84646399226288
# R2 score is 0.38410662408608454
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 53.98040774965494
# R2 score is 0.3909952765044771

# %%
error_frame = pd.DataFrame({'Actual': np.array(Y_test).flatten(), 'Predicted': y_test_predict.flatten()})
error_frame.head(10)
# Out:
#    Actual   Predicted
# 0      76  125.866390
# 1     201  146.282402
# 2      68   85.611016
# 3     135  145.239810
# 4      59  105.842217
# 5     125  190.073092
# 6     209  151.105008
# 7     240  103.532930
# 8     160  185.934384
# 9     183  184.555371

# %%
df1 = error_frame[:50]
df1.plot(kind='bar',figsize=(24,20))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# # This model is much better than before as R2 value is higher and Actual and Predicted model have much better fitting

# %% [markdown]
# ## Finding top hosts and which borough they prefer

# %%
import plotly.graph_objects as go

temp = Join_table.host_id.value_counts().reset_index().head(20)
temp.columns = ['host_id', 'count']
temp = temp.merge(Join_table[['host_id','host_name']], left_on = 'host_id',right_on = 'host_id', how = 'left', copy = False)
temp.drop_duplicates(inplace = True)

x = temp['host_name']
y = temp['count']

# Use the hovertext kw argument for hover text
fig = go.Figure(data=[go.Bar(x=x,y=y)])
# Customize aspect
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5, opacity=0.6)
fig.update_layout(title_text='Top Airbnb hosts in NYC')
fig.layout.xaxis.title = 'Hosts'
fig.layout.yaxis.title = 'Host listings'
fig.show()
# Out:
# <div>
#
#
#             <div id="8efe4886-fde9-4726-9c56-c5f4439c8570" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8efe4886-fde9-4726-9c56-c5f4439c8570")) {
#                     Plotly.newPlot(
#                         '8efe4886-fde9-4726-9c56-c5f4439c8570',
#                         [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "opacity": 0.6, "type": "bar", "x": ["Sonder (NYC)", "Corporate Housing", "Jeremy & Laura", "Kazuya", "Vida", "John", "Kara", "Mike", "Stanley", "Host", "Ken", "Melissa", "Red Awning", "Juliana", "Jeniffer", "Sonder", "Yaacov", "Gabriel", "The Box House Hotel", "AFI Apartments"], "y": [207, 79, 61, 51, 49, 46, 43, 42, 40, 39, 39, 34, 34, 33, 29, 29, 29, 28, 28, 28]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...

# %%
import plotly.express as px
## Setting the DataFrame
temp = Join_table.host_id.value_counts().reset_index().head(5)
temp.columns = ['host_id', 'count']
temp = temp.merge(Join_table[['host_id','host_name','price', 'latitude','longitude']], left_on = 'host_id',right_on = 'host_id', how = 'left', copy = False)

## Setting up the Visualization..
fig = px.scatter_mapbox(temp, 
                        lat="latitude", 
                        lon="longitude", 
                        color="host_name", 
                        size="price",
                        size_max=30, 
                        opacity = .70,
                        zoom=11,
                       )

fig.layout.mapbox.style = 'carto-positron'
fig.update_layout(title_text = 'Top 5 hosts and their hosted Locations<br>(Click legend to toggle hosts)', height = 800)

fig.show()
# Out:
# <div>
#
#
#             <div id="1f9eeb7d-baca-443f-be2d-7989adbddc07" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f9eeb7d-baca-443f-be2d-7989adbddc07")) {
#                     Plotly.newPlot(
#                         '1f9eeb7d-baca-443f-be2d-7989adbddc07',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "host_name=Sonder (NYC)<br>price=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}", "lat": [40.70771, 40.70743, 40.74792, 40.74771, 40.74845, 40.76188, 40.76037, 40.74884, 40.76079, 40.74896, 40.747370000000004, 40.748459999999994, 40.748709999999996, 40.748459999999994, 40.74909, 40.74845, 40.707679999999996, 40.70584, 40.70608, 40.706579999999995, 40.70623, 40.70564, 40.7058, 40.70641, 40.70621, 40.70752, 40.70645, 40.707209999999996, 40.70714, 40.705729999999996, 40.70644, 40.70624, 40.70732, 40.7075, 40.707370000000004, 40.705870000000004, 40.70727, 40.70775, 40.70615, 40.70734, 40.70714, 40.70795, 40.70649, 40.705859999999994, 40.70789, 40.706309999999995, 40.7074, 40.7065, 40.707209999999996, 40.70648, 40.70642, 40.70734, 40.70767, 40.7065, 40.706559999999996, 40.70797, 40.7072, 40.70731, 40.70782, 40.70584, 40.705690000000004, 40.705740000000006, 40.70621, 40.70766, 40.705690000000004, 40.70748, 40.70581, 40.707640000000005, 40.70644, 40.70785, 40.70599, 40.70731, 40.70583, 40.706509999999994, 40.70599, 40.70775, 40.70706, 40.70632, 40.70563, 40.70702, 40.70595, 40.70637, 40.70609, 40.70581, 40.7074, 40.70722, 40.7074, 40.706540000000004, 40.707570000000004, 40.70765, 40.70748, 40.70734, 40.706379999999996